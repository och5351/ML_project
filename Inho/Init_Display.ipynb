# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
import pandas as pd

# %%
inch_lists = [
[' 11 ','11형','11인치','11.'],
[' 12 ','12형','12인치','12.'],
[' 13 ','13형','13인치','13.'],
[' 15 ','15형','15인치','15.'],
[' 16 ','16형','16인치','16.']]

displays = ["11인치(27~29cm)","12인치(29~31cm)","13인치(32~35cm)","15인치(37~39cm)","16인치(40~42cm)"]
inch_size = len(inch_lists)
each_inch_size = len(inch_lists[0])
print('inch_size : ', inch_size)
print('each_inch_size : ', each_inch_size)
for i in range(inch_size):
  print(displays[i])
# Out:
# inch_size :  5
# each_inch_size :  4
# 11인치(27~29cm)
# 12인치(29~31cm)
# 13인치(32~35cm)
# 15인치(37~39cm)
# 16인치(40~42cm)

# %%
def getDisplay(name):
  for i in range(inch_size): # 11인치 ~ 16인치 배열로 비교하자
    for j in range(each_inch_size): # 각 인치당 str size만큼
      result = name.find(inch_lists[i][j])
      if result > -1: # 찾는 문자열 O
        return displays[i]
  return ''

# %%
# 빈 칸 Display 데이터 채우기 전처리
data = pd.read_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/train_display.csv', na_values=['?', '??', 'N/A', 'NA', 'nan', 'NaN', '-nan', '-NaN', 'null', ''],encoding='utf-8')
data = pd.DataFrame(data)
for idx, row in enumerate(data.itertuples()):
  display = data.iat[idx,2] # display Cell 데이터
  if display == 'nan':
    display = getDisplay(name)
    data.iat[idx,2] = display

data.to_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/train_display.csv', index=False)

# %%
for i in range(10):
  print(inp.iat[i,2])
# Out:
# 13인치(32~35cm)
# 13인치(32~35cm)
# 16인치(40~42cm)
# 16인치(40~42cm)
# 13인치(32~35cm)
# nan
# 13인치(32~35cm)
# 13인치(32~35cm)
# 13인치(32~35cm)
# 16인치(40~42cm)

# %%
# 찬해햄 소스 확인용
if __name__ == '__main__':
    
    f = open('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/train_display2.csv', encoding='utf-8')
    reader = csv.reader(f)

    csv_list = []
    for l in reader:
        csv_list.append(l)

    f.close()
    df = pd.DataFrame(csv_list)

    df.to_csv('complete.csv')
