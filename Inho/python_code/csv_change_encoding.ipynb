# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import csv
import pandas as pd

# %%
# cp949 -> utf-8 형식으로 바꾸기
data = pd.read_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/test_display.csv',encoding='cp949')

data.to_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/test_display.csv', index=False, encoding='utf-8')
