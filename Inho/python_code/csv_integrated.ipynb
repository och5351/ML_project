# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import pandas as pd

# %%
# 전처리 데이터 통합하자
year_data = pd.read_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/test_year.csv', na_values=['?', '??', 'N/A', 'NA', 'nan', 'NaN', '-nan', '-NaN', 'null', ''],encoding='utf-8')
year_data = pd.DataFrame(year_data)

complete_data = pd.read_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/test_complete.csv', na_values=['?', '??', 'N/A', 'NA', 'nan', 'NaN', '-nan', '-NaN', 'null', ''],encoding='utf-8')
complete_data = pd.DataFrame(complete_data)


for idx, row in enumerate(cpu_data.itertuples()):
  year_name = year_data.iat[idx,8] # CPU Cell 데이터
  complete_data.iat[idx,8] = year_name

complete_data.to_csv('/content/drive/MyDrive/SK Python/2021.01 프로그래머스 데이터분석/test_complete.csv',index=False, encoding='utf-8')
